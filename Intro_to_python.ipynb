# %% [markdown]
# <a href="https://colab.research.google.com/github/brsi-vit/Machine-Learning-Bootcamp/blob/main/Intro_to_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# VARIABLE

# %%
name="ushnish"
age="20"
gpa=5.5

# %%
print(name)
# Out:
# ushnish

# %%
marks=[85,90,78,92]

# %%
print(marks[0])
print(marks[1])
print(marks[-1])
# Out:
# 85
# 90
# 92

# %%
score=49
if score >= 75:
  print("Pass")
elif score>=50:
  print("Avg")
else:
  print("Fail")
# Out:
# Fail

# %%
def square(x):
  return x**2

# %%
print(square(5))
# Out:
# 25

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
arr = np.array([10,20,30])

# %%
print(arr*2)
print(arr.mean())
print(arr.std())
# Out:
# [20 40 60]
# 20.0
# 8.16496580927726

# %%
matrix = np.array([[1,2],[3,4],[5,6]])
print(matrix)
print(matrix.shape)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# (3, 2)

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'San Francisco', 'Los Angeles']
}
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
print(df.shape)
print(df.head(10))
print(df.info())
print(df.describe())
# Out:
# (3, 3)
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
ages = [22,25,28,30]
score = [92,88,76,67]

plt.figure(figsize=(6,4))
plt.scatter(ages, score)
